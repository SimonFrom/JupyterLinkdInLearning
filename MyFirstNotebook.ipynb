# %%
import matplotlib.pyplot as plt

# %%
print("Hello there")
# Out:
# Hello there

# %%
greeting = "Hello there dude"

# %% [markdown]
# ### Length of words in var greeting

# %%
words = greeting.split(" ")

word_length = [len(w) for w in words]
plt.bar(words, word_length)
plt.show()
