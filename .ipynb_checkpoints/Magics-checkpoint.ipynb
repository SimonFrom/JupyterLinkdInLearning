# %%
import pandas as pd
df = pd.read_csv('Ex_Files_Introducing_Jupyter/Ex_Files_Introducing_Jupyter/Exercise Files/inputs/Environmental_Data_Deep_Moor_2013.csv')

def get_day(d):
  return df[df['date']==d]

# %%
get_day('2015_01_01')
# Out:
# Empty DataFrame
# Columns: [date, time, Air_Temp, Barometric_Press, Dew_Point, Relative_Humidity, Wind_Dir, Wind_Gust, Wind_Speed]
# Index: []
